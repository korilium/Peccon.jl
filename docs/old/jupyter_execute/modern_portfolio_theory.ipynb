# %% [markdown]
# # Modern Portfolio Theory

# %%
using Peccon, Plots, StatsPlots
# Out:
#   Cell In[1], line 1
#     using Peccon, Plots, StatsPlots
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## load in data

# %%
tickers = ["ADAEUR", "SPY", "DIS"]
data = Peccon.fin_data(tickers)
# Out:
# 3-element Vector{Any}:
#  250×10 DataFrame
#  Row │ timestamp   open      high      low       close     adjusted_close  vol ⋯
#      │ SubStrin…   Float64   Float64   Float64   Float64   Float64         Int ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2023-03-22  0.342859  0.350561  0.338869  0.342859        0.342859   29 ⋯
#    2 │ 2023-03-21  0.308156  0.359097  0.305372  0.342952        0.342952  288
#    3 │ 2023-03-20  0.31994   0.321146  0.306671  0.308156        0.308156  124
#    4 │ 2023-03-19  0.312702  0.327085  0.312424  0.31994         0.31994    93
#    5 │ 2023-03-18  0.324208  0.331446  0.310847  0.312795        0.312795  160 ⋯
#    6 │ 2023-03-17  0.301475  0.324951  0.298041  0.324208        0.324208  171
#    7 │ 2023-03-16  0.30064   0.305279  0.294237  0.301475        0.301475  148
#    8 │ 2023-03-15  0.318177  0.321425  0.292938  0.300732        0.300732  262
#   ⋮  │     ⋮          ⋮         ⋮         ⋮         ⋮            ⋮             ⋱
#  244 │ 2022-07-22  0.463393  0.474528  0.442608  0.44799         0.44799   200 ⋯
#  245 │ 2022-07-21  0.455599  0.466084  0.441309  0.4633          0.4633    261
#  246 │ 2022-07-20  0.478054  0.509139  0.451702  0.455599        0.455599  389
#  247 │ 2022-07-19  0.455042  0.488075  0.439175  0.478054        0.478054  386
#  248 │ 2022-07-18  0.415514  0.463764  0.413565  0.455042        0.455042  383 ⋯
#  249 │ 2022-07-17  0.424793  0.432401  0.410225  0.415514        0.415514  153
#  250 │ 2022-07-16  0.410225  0.425999  0.400482  0.424793        0.424793  147
#                                                   4 columns and 235 rows omitted
#  250×10 DataFrame
#  Row │ timestamp   open     high     low      close    adjusted_close  volume  ⋯
#      │ SubStrin…   Float64  Float64  Float64  Float64  Float64         Int64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2023-03-21   397.24  399.41   395.58    398.91         398.91    915242 ⋯
#    2 │ 2023-03-20   390.8   394.17   390.07    393.74         393.74    930557
#    3 │ 2023-03-17   393.22  394.4    388.55    389.99         389.99   1405534
#    4 │ 2023-03-16   386.82  396.47   386.29    396.11         394.586  1437539
#    5 │ 2023-03-15   385.89  389.49   383.71    389.28         387.782  1729969 ⋯
#    6 │ 2023-03-14   390.5   393.45   387.05    391.73         390.223  1497523
#    7 │ 2023-03-13   381.81  390.39   380.65    385.36         383.877  1577899
#    8 │ 2023-03-10   390.99  393.16   384.32    385.91         384.425  1892529
#   ⋮  │     ⋮          ⋮        ⋮        ⋮        ⋮           ⋮             ⋮   ⋱
#  244 │ 2022-03-31   457.89  458.76   451.16    451.64         444.061  1216999 ⋯
#  245 │ 2022-03-30   460.34  461.195  456.465   458.7          451.002   796669
#  246 │ 2022-03-29   460.02  462.07   457.18    461.55         453.804   865815
#  247 │ 2022-03-28   452.06  455.91   450.06    455.91         448.259   685297
#  248 │ 2022-03-25   451.16  452.98   448.43    452.69         445.093   761236 ⋯
#  249 │ 2022-03-24   445.94  450.5    444.76    450.49         442.93    647368
#  250 │ 2022-03-23   446.91  448.49   443.71    443.8          436.352   794260
#                                                   4 columns and 235 rows omitted
#  250×10 DataFrame
#  Row │ timestamp   open     high      low      close    adjusted_close  volume ⋯
#      │ SubStrin…   Float64  Float64   Float64  Float64  Float64         Int64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2023-03-21   95.17    96.85     95.17     96.54           96.54   72857 ⋯
#    2 │ 2023-03-20   93.43    94.92     93.0      94.22           94.22   66571
#    3 │ 2023-03-17   94.05    94.27     92.91     93.2            93.2   129431
#    4 │ 2023-03-16   92.67    94.5599   91.89     94.29           94.29   99466
#    5 │ 2023-03-15   91.63    93.3557   91.41     93.1            93.1    95438 ⋯
#    6 │ 2023-03-14   94.0     94.3      92.34     93.36           93.36  103236
#    7 │ 2023-03-13   91.885   94.0242   90.46     92.6            92.6   119153
#    8 │ 2023-03-10   95.6     95.9      92.83     93.57           93.57  139788
#   ⋮  │     ⋮          ⋮        ⋮         ⋮        ⋮           ⋮            ⋮   ⋱
#  244 │ 2022-03-31  140.14   140.88    137.11    137.16          137.16  123064 ⋯
#  245 │ 2022-03-30  141.31   143.268   140.08    140.96          140.96   79224
#  246 │ 2022-03-29  140.96   144.46    140.96    142.38          142.38  112806
#  247 │ 2022-03-28  138.88   139.627   136.282   138.72          138.72   84560
#  248 │ 2022-03-25  139.28   140.38    138.12    139.14          139.14   58650 ⋯
#  249 │ 2022-03-24  138.58   139.27    137.41    138.96          138.96   58587
#  250 │ 2022-03-23  139.07   139.76    137.54    137.64          137.64   87612
#                                                   4 columns and 235 rows omitted

# %% [markdown]
# ## Calculate Returns and Simulate Portfolios

# %%
returns = Peccon.calc_returns(data, tickers)

sim_port = Peccon.sim_mpt(returns)
# Out:
# 5000×6 DataFrame
#   Row │ exp_return  port_var   weight_ADAEUR  weight_SPY  weight_DIS  port_std ⋯
#       │ Float64     Float64    Float64        Float64     Float64     Float64  ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │   0.211793  0.0727605       0.304469   0.403728   0.291803    0.269741 ⋯
#     2 │   0.150251  0.0609467       0.277358   0.667179   0.0554624   0.246874
#     3 │   0.268861  0.0964866       0.374065   0.134261   0.491673    0.310623
#     4 │   0.254929  0.150795        0.591846   0.0671588  0.340995    0.388323
#     5 │   0.27137   0.0805039       0.159949   0.245345   0.594705    0.283732 ⋯
#     6 │   0.160185  0.0779028       0.37698    0.570742   0.0522773   0.279111
#     7 │   0.208328  0.0764382       0.335187   0.400311   0.264502    0.276475
#     8 │   0.201054  0.196987        0.717368   0.213308   0.0693234   0.443832
#   ⋮   │     ⋮           ⋮            ⋮            ⋮           ⋮          ⋮     ⋱
#  4994 │   0.141649  0.0602616       0.277052   0.702032   0.020916    0.245482 ⋯
#  4995 │   0.216504  0.065235        0.200644   0.443505   0.355851    0.255411
#  4996 │   0.157424  0.0988669       0.46463    0.532261   0.00310962  0.314431
#  4997 │   0.173526  0.104677        0.481938   0.457547   0.0605153   0.323538
#  4998 │   0.206861  0.0699998       0.017978   0.585773   0.396249    0.264575 ⋯
#  4999 │   0.177957  0.116299        0.519188   0.418597   0.0622148   0.341027
#  5000 │   0.206389  0.0721497       0.307515   0.423788   0.268697    0.268607
#                                                               4985 rows omitted

# %%
@df sim_port scatter( :port_std, :exp_return)

# %%
sharp = Peccon.sharp_ratio(sim_port)
sharp[end, :]
# Out:
# DataFrameRow
#   Row │ exp_return  port_var  weight_ADAEUR  weight_SPY  weight_DIS  port_std  ⋯
#       │ Float64     Float64   Float64        Float64     Float64     Float64   ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#  5000 │   0.330983  0.104946       0.144712    0.013638     0.84165  0.323954  ⋯
#                                                                 1 column omitted
