# %% [markdown]
# # Modern Portfolio Theory

# %%
using Peccon, Plots, StatsPlots
# Out:
#   Cell In[1], line 1
#     using Peccon, Plots, StatsPlots
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## load in data

# %%
tickers = ["ADAEUR", "SPY", "DIS"]
data = Peccon.fin_data(tickers)
# Out:
# 3-element Vector{Any}:
#  250×10 DataFrame
#  Row │ timestamp   open      high      low       close     adjusted_close  vol ⋯
#      │ SubStrin…   Float64   Float64   Float64   Float64   Float64         Int ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2023-03-19  0.315803  0.322644  0.315522  0.319645        0.319645   12 ⋯
#    2 │ 2023-03-18  0.327423  0.334732  0.313929  0.315896        0.315896  160
#    3 │ 2023-03-17  0.304464  0.328172  0.300997  0.327423        0.327423  171
#    4 │ 2023-03-16  0.30362   0.308306  0.297154  0.304464        0.304464  148
#    5 │ 2023-03-15  0.321332  0.324611  0.295842  0.303714        0.303714  262 ⋯
#    6 │ 2023-03-14  0.3218    0.344572  0.315147  0.321332        0.321332  243
#    7 │ 2023-03-13  0.309056  0.329578  0.306807  0.321706        0.321706  290
#    8 │ 2023-03-12  0.285909  0.310274  0.282348  0.309056        0.309056  148
#   ⋮  │     ⋮          ⋮         ⋮         ⋮         ⋮            ⋮             ⋱
#  244 │ 2022-07-19  0.459554  0.492915  0.443529  0.482794        0.482794  386 ⋯
#  245 │ 2022-07-18  0.419633  0.468363  0.417665  0.459554        0.459554  383
#  246 │ 2022-07-17  0.429004  0.436689  0.414292  0.419633        0.419633  153
#  247 │ 2022-07-16  0.414292  0.430223  0.404452  0.429004        0.429004  147
#  248 │ 2022-07-15  0.413917  0.425069  0.405389  0.414292        0.414292  187 ⋯
#  249 │ 2022-07-14  0.410731  0.418415  0.390771  0.413823        0.413823  208
#  250 │ 2022-07-13  0.390864  0.414386  0.376995  0.410731        0.410731  265
#                                                   4 columns and 235 rows omitted
#  250×10 DataFrame
#  Row │ timestamp   open     high     low      close    adjusted_close  volume  ⋯
#      │ SubStrin…   Float64  Float64  Float64  Float64  Float64         Int64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2023-03-17   393.22  394.4    388.55    389.99         389.99   1405534 ⋯
#    2 │ 2023-03-16   386.82  396.47   386.29    396.11         394.586  1437539
#    3 │ 2023-03-15   385.89  389.49   383.71    389.28         387.782  1729969
#    4 │ 2023-03-14   390.5   393.45   387.05    391.73         390.223  1497523
#    5 │ 2023-03-13   381.81  390.39   380.65    385.36         383.877  1577899 ⋯
#    6 │ 2023-03-10   390.99  393.16   384.32    385.91         384.425  1892529
#    7 │ 2023-03-09   399.74  401.48   390.53    391.56         390.054  1119453
#    8 │ 2023-03-08   398.39  399.71   396.59    398.92         397.385   747466
#   ⋮  │     ⋮          ⋮        ⋮        ⋮        ⋮           ⋮             ⋮   ⋱
#  244 │ 2022-03-29   460.02  462.07   457.18    461.55         453.804   865815 ⋯
#  245 │ 2022-03-28   452.06  455.91   450.06    455.91         448.259   685297
#  246 │ 2022-03-25   451.16  452.98   448.43    452.69         445.093   761236
#  247 │ 2022-03-24   445.94  450.5    444.76    450.49         442.93    647368
#  248 │ 2022-03-23   446.91  448.49   443.71    443.8          436.352   794260 ⋯
#  249 │ 2022-03-22   445.86  450.58   445.86    449.59         442.045   734648
#  250 │ 2022-03-21   444.34  446.46   440.68    444.39         436.932   873501
#                                                   4 columns and 235 rows omitted
#  250×10 DataFrame
#  Row │ timestamp   open     high      low      close    adjusted_close  volume ⋯
#      │ SubStrin…   Float64  Float64   Float64  Float64  Float64         Int64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2023-03-17   94.05    94.27     92.91     93.2            93.2   129431 ⋯
#    2 │ 2023-03-16   92.67    94.5599   91.89     94.29           94.29   99466
#    3 │ 2023-03-15   91.63    93.3557   91.41     93.1            93.1    95438
#    4 │ 2023-03-14   94.0     94.3      92.34     93.36           93.36  103236
#    5 │ 2023-03-13   91.885   94.0242   90.46     92.6            92.6   119153 ⋯
#    6 │ 2023-03-10   95.6     95.9      92.83     93.57           93.57  139788
#    7 │ 2023-03-09   99.45   100.05     95.92     96.14           96.14   82755
#    8 │ 2023-03-08   99.0     99.62     98.3      99.3            99.3    56687
#   ⋮  │     ⋮          ⋮        ⋮         ⋮        ⋮           ⋮            ⋮   ⋱
#  244 │ 2022-03-29  140.96   144.46    140.96    142.38          142.38  112806 ⋯
#  245 │ 2022-03-28  138.88   139.627   136.282   138.72          138.72   84560
#  246 │ 2022-03-25  139.28   140.38    138.12    139.14          139.14   58650
#  247 │ 2022-03-24  138.58   139.27    137.41    138.96          138.96   58587
#  248 │ 2022-03-23  139.07   139.76    137.54    137.64          137.64   87612 ⋯
#  249 │ 2022-03-22  139.06   142.19    138.9     140.11          140.11   82553
#  250 │ 2022-03-21  138.9    139.3     136.88    138.62          138.62   89022
#                                                   4 columns and 235 rows omitted

# %% [markdown]
# ## Calculate Returns and Simulate Portfolios

# %%
returns = Peccon.calc_returns(data, tickers)

sim_port = Peccon.sim_mpt(returns)
# Out:
# 5000×6 DataFrame
#   Row │ exp_return  port_var   weight_ADAEUR  weight_SPY  weight_DIS  port_std ⋯
#       │ Float64     Float64    Float64        Float64     Float64     Float64  ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │   0.24752   0.101321      0.486984      0.293695   0.219321   0.318309 ⋯
#     2 │   0.308487  0.0913915     0.384508      0.121104   0.494388   0.30231
#     3 │   0.269885  0.0720062     0.310063      0.306876   0.383061   0.26834
#     4 │   0.273955  0.0742271     0.321815      0.285147   0.393038   0.272446
#     5 │   0.232842  0.0687991     0.339337      0.429851   0.230812   0.262296 ⋯
#     6 │   0.300462  0.09227       0.401529      0.141884   0.456587   0.30376
#     7 │   0.371632  0.118734      0.00561896    0.092097   0.902284   0.344577
#     8 │   0.203089  0.126807      0.580257      0.409264   0.0104788  0.356099
#   ⋮   │     ⋮           ⋮            ⋮            ⋮           ⋮          ⋮     ⋱
#  4994 │   0.220288  0.11967       0.557032      0.357456   0.0855118  0.345934 ⋯
#  4995 │   0.208549  0.0964643     0.484279      0.441461   0.0742602  0.310587
#  4996 │   0.143084  0.0503596     0.0491196     0.926103   0.0247776  0.22441
#  4997 │   0.229272  0.0568895     0.143754      0.550628   0.305618   0.238515
#  4998 │   0.256768  0.0624332     0.161934      0.437437   0.400629   0.249866 ⋯
#  4999 │   0.229447  0.111702      0.53005       0.337889   0.132061   0.334219
#  5000 │   0.196594  0.095781      0.4846        0.486161   0.0292394  0.309485
#                                                               4985 rows omitted

# %%
@df sim_port scatter( :port_std, :exp_return)

# %%
sharp = Peccon.sharp_ratio(sim_port)
sharp[end, :]
# Out:
# DataFrameRow
#   Row │ exp_return  port_var   weight_ADAEUR  weight_SPY  weight_DIS  port_std ⋯
#       │ Float64     Float64    Float64        Float64     Float64     Float64  ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#  5000 │   0.366074  0.0969304       0.196459  0.00818629    0.795355  0.311336 ⋯
#                                                                 1 column omitted
