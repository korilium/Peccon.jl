# %% [markdown]
# # Modern Portfolio Theory

# %%
using Peccon

# %% [markdown]
# ## load in data

# %%
tickers = ["ADAEUR", "SPY", "DIS"]
data = Peccon.fin_data(tickers)
# Out:
# 250×3 DataFrame
#  Row │ ADAEUR       SPY           DIS
#      │ Float64      Float64       Float64
# ─────┼────────────────────────────────────────
#    1 │  0.0          0.0           0.0
#    2 │ -0.0117961    0.0155709     0.0116274
#    3 │  0.0358378   -0.0173931    -0.012701
#    4 │ -0.0727       0.00627395    0.0027888
#    5 │ -0.00246533  -0.0163949    -0.00817385
#    6 │  0.0563867    0.00142622    0.0104207
#    7 │  0.00116584   0.0145346     0.0270956
#    8 │ -0.0401183    0.0186221     0.0323401
#   ⋮  │      ⋮            ⋮             ⋮
#  244 │  0.048111     0.00619399    0.0100234
#  245 │ -0.0493338   -0.012295     -0.026042
#  246 │ -0.0908747   -0.00708786    0.00302311
#  247 │  0.0220857   -0.00487169   -0.0012945
#  248 │ -0.0348963   -0.0149619    -0.00954454
#  249 │ -0.00113161   0.012962      0.0177862
#  250 │ -0.00750089  -0.0116335    -0.0106915
#                               235 rows omitted

# %% [markdown]
# ## Calculate Returns and Simulate Portfolios

# %%
returns = Peccon.calc_returns(data, tickers)

sim_port = Peccon.sim_mpt(returns)
# Out:
# 5000×6 DataFrame
#   Row │ exp_return  port_var   weight_ADAEUR  weight_SPY  weight_DIS  port_std ⋯
#       │ Float64     Float64    Float64        Float64     Float64     Float64  ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │   0.262121  0.0681369      0.28793      0.34817    0.3639     0.261031 ⋯
#     2 │   0.206672  0.0535611      0.121302     0.647786   0.230912   0.231433
#     3 │   0.202181  0.11084        0.533681     0.438242   0.0280767  0.332927
#     4 │   0.18957   0.0592003      0.0200299    0.767579   0.212391   0.243311
#     5 │   0.25824   0.0641516      0.12388      0.452803   0.423317   0.253282 ⋯
#     6 │   0.290323  0.0714653      0.230422     0.27388    0.495698   0.26733
#     7 │   0.222145  0.0557947      0.134737     0.582331   0.282932   0.236209
#     8 │   0.2181    0.0568087      0.245366     0.536776   0.217857   0.238346
#   ⋮   │     ⋮           ⋮            ⋮            ⋮           ⋮          ⋮     ⋱
#  4994 │   0.199482  0.0737076      0.391272     0.526558   0.0821697  0.271491 ⋯
#  4995 │   0.249481  0.0624405      0.116242     0.489875   0.393883   0.249881
#  4996 │   0.292973  0.107307       0.479411     0.127238   0.393351   0.327577
#  4997 │   0.243192  0.0593421      0.195212     0.470127   0.334661   0.243602
#  4998 │   0.208091  0.0783511      0.410251     0.483822   0.105926   0.279913 ⋯
#  4999 │   0.207515  0.0905654      0.462495     0.457304   0.0802008  0.300941
#  5000 │   0.222596  0.113013       0.536172     0.360243   0.103585   0.336174
#                                                               4985 rows omitted
